# %% [markdown]
# ### 성경 개역한글 대한성서공회  20231012
#
# https://www.bskorea.or.kr/bible/korbibReadpage.php?version=HAN&book=gen&chap=1&sec=1&cVersion=&fontSize=15px&fontWeight=normal

# %%
# 2023-10-12 22:49:56.680544

from datetime import datetime

print(datetime.now())
# Out:
# 2023-10-12 22:49:56.680544

# %% [markdown]
# ### References:
#
# [Python] 웹 크롤링 및 텍스트 파싱을 이용한 성경 다운로더¶
#
# https://cpuu.postype.com/post/26176

# %%
# %%time

# # %%writefile D:\Korean_bible_project\korean_bible.py

# import os
# import requests
# import pandas as pd
# from bs4 import BeautifulSoup
# from pprint import pprint
# from tqdm import tqdm


# bibles = [['01창세기', 'gen', '50'], ['02출애굽기', 'exo', '40'], ['03레위기', 'lev', '27'], 
#  ['04민수기', 'num', '36'], ['05신명기', 'deu', '34'], ['06여호수아', 'jos', '24'], 
#  ['07사사기', 'jdg', '21'], ['08룻기', 'rut', '4'], ['09사무엘상', '1sa', '31'], 
#  ['10사무엘하', '2sa', '24'], ['11열왕기상', '1ki', '22'], ['12열왕기하', '2ki', '25'], 
#  ['13역대상', '1ch', '29'], ['14역대하', '2ch', '36'], ['15에스라', 'ezr', '10'], 
#  ['16느헤미야', 'neh', '13'], ['17에스더', 'est', '10'], ['18욥기', 'job', '42'], 
#  ['19시편', 'psa', '150'], ['20잠언', 'pro', '31'], ['21전도서', 'ecc', '12'], 
#  ['22아가', 'sng', '8'], ['23이사야', 'isa', '66'], ['24예레미야', 'jer', '52'], 
#  ['25예레미야애가', 'lam', '5'], ['26에스겔', 'ezk', '48'], ['27다니엘', 'dan', '12'], 
#  ['28호세아', 'hos', '14'], ['29요엘', 'jol', '3'], ['30아모스', 'amo', '9'],
#  ['31오바댜', 'oba', '1'], ['32요나', 'jnh', '4'], ['33미가', 'mic', '7'], ['34나훔', 'nam', '3'], 
#  ['35하박국', 'hab', '3'], ['36스바냐', 'zep', '3'], ['37학개', 'hag', '2'], 
#  ['38스가랴', 'zec', '14'], ['39말라기', 'mal', '4'], ['40마태복음', 'mat', '28'],
#  ['41마가복음', 'mrk', '16'], ['42누가복음', 'luk', '24'], ['43요한복음', 'jhn', '21'],
#  ['44사도행전', 'act', '28'], ['45로마서', 'rom', '16'], ['46고린도전서', '1co', '16'],
#  ['47고린도후서', '2co', '13'], ['48갈라디아서', 'mal', '6'], ['49에베소서', 'eph', '6'], 
#  ['50빌립보서', 'php', '4'], ['51골로새서', 'col', '4'], ['52데살로니가전서', '1th', '5'],
#  ['53데살로니가후서', '2th', '3'], ['54디모데전서', '1ti', '6'], ['55디모데후서', '2ti', '4'], 
#  ['56디도서', 'tit', '3'], ['57빌레몬서', 'phm', '1'], ['58히브리서', 'heb', '13'],
#  ['59야고보서', 'jas', '5'], ['60베드로전서', '1pe', '5'], ['61베드로후서', '2pe', '3'], 
#  ['62요한1서', '1jn', '5'], ['63요한2서', '2jn', '1'], ['64요한3서', '3jn', '1'],
#  ['65유다서', 'jud', '1'], ['66요한계시록', 'rev', '22']]

# bibles = [ (bible[0], bible[1], int(bible[2])) for bible in bibles]
# # print(len(bibles))
# # print(bibles)
# # print(bibles[36])
# base_url = 'http://www.bskorea.or.kr/infobank'
 

# def get_chapter_url( book_en, chapter):
#     # url = f"{base_url}/korSearch/korbibReadpage.aspx?version=HAN&book={book}&chap={chapter}"
#     url = f'http://www.bskorea.or.kr/bible/korbibReadpage.php?version=HAN&book={book_en}&chap={chapter}'
#     return url


# def get_soup(book_en, chapter):
#     url = get_chapter_url( book_en, chapter)
#     print(url)
#     response = requests.get(url)
#     if response.status_code == 200:
#         soup = BeautifulSoup(response.content, 'lxml')
#     else:
#         print(f'Error: {response.status_code}')
#         soup = None
#     return soup


# def get_bible_chapter_contents(book, book_en, chapter):
#     soup = get_soup(book_en, chapter)
#     small_title = soup.find('font', class_='smallTitle').text
#     idx = 0
#     chap_df = pd.DataFrame(columns=['book','book_en','chapter', 'verse_no', 'verse', 'small_title' ])
#     for item in tqdm(soup.find_all('span'), desc='get_bible_chapter_contents'):
#         flag = False
#         if item.find('span', class_='number'):
#             num = item.find('span', class_='number').text
#         text = item.text
#         if text != num:
#             if text == '성경 단어 검색':
#                 flag = True
#                 break
#             else:
#                 # print(text)
#                 verse_num = text.split('\xa0\xa0\xa0')[0].strip()
#                 verse = text.split('\xa0\xa0\xa0')[1].strip()
#                 chap_df.loc[idx] = [book, book_en, chapter, num, verse, small_title ]
#                 idx +=1
#         if flag:
#             break
#     return  chap_df


# def get_bible_book_contents(book, book_en, max_chap_num, path):
#     book_df = pd.DataFrame()
#     for num in tqdm(range(max_chap_num), desc='et_bible_book_contents'):
#         chapter = num + 1
#         chap_df = get_bible_chapter_contents(book=book, book_en=book_en, chapter=chapter)
#         book_df = pd.concat([book_df, chap_df], ignore_index=True)
#     filename = f'{book}.csv'    
#     filepath = os.path.join(path, filename)
#     book_df.to_csv(filepath, index=False)
#     print(f'"{filepath}" is saved.')
#     return book_df


# def get_all_bible_contents(bibles, path):
#     for bible in tqdm(bibles, desc='get_all_bible_contents'):
#         print(bible)
#         book = bible[0]
#         filename = f'filename: {book}.csv'
#         book_no = bible[0][ :2].strip()
#         book_name_ko = bible[0][2: ].strip()
#         book_name_en = bible[1].strip()
#         max_chap_num = bible[2]
#         print(f'{filename}')
#         print(f'{book_no}: {book_name_ko} {book_name_en} {max_chap_num}')
#         book_df = get_bible_book_contents(book, book_en, max_chap_num, path)

    

# print(f'\n1.Collecting Bible Chapter Contents.')

# # book = '창세기'
# # book_en = 'gen'  # 창세기
# # chapter = 1  # 1장을 가져온다.

# # soup = get_soup(book_en, chapter)
# # chap_num = soup.find('font', class_='chapNum').text
# # small_title = soup.find('font', class_='smallTitle').text
# # print(chap_num)
# # print(small_title)
# # df =  get_bible_chapter_contents(book, book_en, chapter)
# # display(df)

      
# print(f'\n2.Collecting Bible Book Contents.')

# # # CPU times: total: 5.23 s
# # # Wall time: 1min 20s
# # book = '창세기'
# # book_en = 'gen'
# # max_chap_num = 50
# # path = r'D:\Korean_bible_project\notebook\data'
# # book_df = get_bible_book_contents(book, book_en, max_chap_num, path)

# print(f'\n3.Collecting All Bible Contents.')

# path = r'D:\Korean_bible_project\notebook\data'
# get_all_bible_contents(bibles, path)
# Out:
# Overwriting D:\Korean_bible_project\korean_bible.py
# CPU times: total: 0 ns
# Wall time: 1.99 ms

# %%
# %%time

# %%writefile D:\Korean_bible_project\korean_bible.py
    
"""
korean_bible.py

This module collect Korean bible verses from the "대한성서공회  웹사이트"
http://www.bskorea.or.kr

Author: CB Park
Date: Oct. 12, 2023
"""    

import os
import requests
import pandas as pd
from bs4 import BeautifulSoup
from pprint import pprint
from tqdm import tqdm


BIBLES = [['01창세기', 'gen', '50'], ['02출애굽기', 'exo', '40'], ['03레위기', 'lev', '27'], 
 ['04민수기', 'num', '36'], ['05신명기', 'deu', '34'], ['06여호수아', 'jos', '24'], 
 ['07사사기', 'jdg', '21'], ['08룻기', 'rut', '4'], ['09사무엘상', '1sa', '31'], 
 ['10사무엘하', '2sa', '24'], ['11열왕기상', '1ki', '22'], ['12열왕기하', '2ki', '25'], 
 ['13역대상', '1ch', '29'], ['14역대하', '2ch', '36'], ['15에스라', 'ezr', '10'], 
 ['16느헤미야', 'neh', '13'], ['17에스더', 'est', '10'], ['18욥기', 'job', '42'], 
 ['19시편', 'psa', '150'], ['20잠언', 'pro', '31'], ['21전도서', 'ecc', '12'], 
 ['22아가', 'sng', '8'], ['23이사야', 'isa', '66'], ['24예레미야', 'jer', '52'], 
 ['25예레미야애가', 'lam', '5'], ['26에스겔', 'ezk', '48'], ['27다니엘', 'dan', '12'], 
 ['28호세아', 'hos', '14'], ['29요엘', 'jol', '3'], ['30아모스', 'amo', '9'],
 ['31오바댜', 'oba', '1'], ['32요나', 'jnh', '4'], ['33미가', 'mic', '7'], ['34나훔', 'nam', '3'], 
 ['35하박국', 'hab', '3'], ['36스바냐', 'zep', '3'], ['37학개', 'hag', '2'], 
 ['38스가랴', 'zec', '14'], ['39말라기', 'mal', '4'], ['40마태복음', 'mat', '28'],
 ['41마가복음', 'mrk', '16'], ['42누가복음', 'luk', '24'], ['43요한복음', 'jhn', '21'],
 ['44사도행전', 'act', '28'], ['45로마서', 'rom', '16'], ['46고린도전서', '1co', '16'],
 ['47고린도후서', '2co', '13'], ['48갈라디아서', 'gal', '6'], ['49에베소서', 'eph', '6'], 
 ['50빌립보서', 'php', '4'], ['51골로새서', 'col', '4'], ['52데살로니가전서', '1th', '5'],
 ['53데살로니가후서', '2th', '3'], ['54디모데전서', '1ti', '6'], ['55디모데후서', '2ti', '4'], 
 ['56디도서', 'tit', '3'], ['57빌레몬서', 'phm', '1'], ['58히브리서', 'heb', '13'],
 ['59야고보서', 'jas', '5'], ['60베드로전서', '1pe', '5'], ['61베드로후서', '2pe', '3'], 
 ['62요한1서', '1jn', '5'], ['63요한2서', '2jn', '1'], ['64요한3서', '3jn', '1'],
 ['65유다서', 'jud', '1'], ['66요한계시록', 'rev', '22']]

BIBLES = [ (bible[0], bible[1], int(bible[2])) for bible in BIBLES]
BASE_URL = 'http://www.bskorea.or.kr'
 

class KoreanBible():
        
    def get_chapter_url(self, book_en, chapter):
        url = f'{BASE_URL}/bible/korbibReadpage.php?version=HAN&book={book_en}&chap={chapter}'
        return url

    def get_soup(self, book_en, chapter):
        url = self.get_chapter_url( book_en=book_en, chapter=chapter)
        print(url)
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'lxml')
        else:
            print(f'Error: {response.status_code}')
            soup = None
        return soup

    def get_bible_chapter_contents(self, book, book_en, chapter):
        soup = self.get_soup(book_en, chapter)
        if soup.find('font', class_='smallTitle'):
            small_title = soup.find('font', class_='smallTitle').text
        else:
            small_title = None
        idx = 0
        chap_df = pd.DataFrame(columns=['book','book_en','chapter', 'verse_no', 'verse', 'small_title' ])
        for item in tqdm(soup.find_all('span'), desc='get_bible_chapter_contents'):
            flag = False
            if item.find('span', class_='number'):
                num = item.find('span', class_='number').text
            text = item.text
            if text != num:
                if text == '성경 단어 검색':
                    flag = True
                    break
                else:
                    # print(text)
                    verse_num = text.split('\xa0\xa0\xa0')[0].strip()
                    verse = text.split('\xa0\xa0\xa0')[1].strip()
                    chap_df.loc[idx] = [book, book_en, chapter, num, verse, small_title ]
                    idx +=1
            if flag:
                break
        return  chap_df
    
    def parse_bible_meta_data(self, bible, verbose=True):
        if verbose: print(bible)
        book = bible[0]
        filename = f'{book}.csv'
        book_no = bible[0][ :2].strip()
        book_ko = bible[0][2: ].strip()
        book_en = bible[1].strip()
        max_chap_num = bible[2]
        if verbose: print(filename, book_no, book_ko,  book_en, max_chap_num)
        return filename, book_no, book_ko, book_en, max_chap_num

    def get_bible_book_contents(self, bible, path):
        filename, book_no, book_ko, book_en, max_chap_num = self.parse_bible_meta_data(
                                                                           bible, verbose=False)
        book_df = pd.DataFrame()
        for num in tqdm(range(max_chap_num), desc='get_bible_book_contents'):
            chapter = num + 1
            chap_df = self.get_bible_chapter_contents(book=book_ko, book_en=book_en, chapter=chapter)
            book_df = pd.concat([book_df, chap_df], ignore_index=True) 
        filepath = os.path.join(path, filename)
        book_df.to_csv(filepath, index=False)
        print(f'"{filepath}" is saved.')
        return book_df

    def get_all_bible_contents(self, bibles, path):
        for bible in tqdm(bibles, desc='get_all_bible_contents'):
            print(bible)
            self.get_bible_book_contents(bible, path)

    
def main():
    
    print(f'\n1.Collecting Bible Chapter Contents.')
    
#     # ['01창세기', 'gen', '50']
#     bible = BIBLES[0]
#     print(bible)

#     kb = KoreanBible()
#     chapter = 1
#     filename, book_no, book_ko, book_en, max_chap_num = kb.parse_bible_meta_data(bible, 
#                                                                                  verbose=False)
#     soup = kb.get_soup(book_en, chapter)
#     chap_num = soup.find('font', class_='chapNum').text
#     small_title = soup.find('font', class_='smallTitle').text
#     print(chap_num)
#     print(small_title)
    
#     df =  kb.get_bible_chapter_contents(book_ko, book_en, chapter)
#     display(df)


    print(f'\n2.Collecting Bible Book Contents.')
    
#     # ['06여호수아', 'jos', '24']
#     bible = BIBLES[5]
#     print(bible)
#     kb = KoreanBible()
#     filename, book_no, book_ko, book_en, max_chap_num = kb.parse_bible_meta_data(bible, 
#                                                                                  verbose=False)
#     path = '.\data'
#     book_df = kb.get_bible_book_contents(bible, path)
    

    print(f'\n3.Collecting All Bible Contents.')
    # CPU times: total: 1min 53s
    # Wall time: 31min 23s

#     path = '.\data'
#     kb = KoreanBible()
#     kb.get_all_bible_contents(BIBLES, path)

if __name__ == '__main__':
    main()
# Out:
# Overwriting D:\Korean_bible_project\korean_bible.py
# CPU times: total: 0 ns
# Wall time: 2 ms

# %%
os.getcwd()
# Out:
# 'D:\\Korean_bible_project\\notebook'

# %% [markdown]
# ### 성경_개역한글_meta_data

# %%
import pickle

bibles = [ (bible[0], bible[1], int(bible[2])) for bible in BIBLES]
print(len(bibles))
# print(bibles)

# with open('../bibles/성경_개역한글_meta_data.pkl', 'wb') as f:
#     pickle.dump(bibles, f)
    
with open('../bibles/성경_개역한글_meta_data.pkl', 'rb') as f:
    bible_metadata = pickle.load(f)
print(bible_metadata)
# Out:
# 66
# [('01창세기', 'gen', 50), ('02출애굽기', 'exo', 40), ('03레위기', 'lev', 27), ('04민수기', 'num', 36), ('05신명기', 'deu', 34), ('06여호수아', 'jos', 24), ('07사사기', 'jdg', 21), ('08룻기', 'rut', 4), ('09사무엘상', '1sa', 31), ('10사무엘하', '2sa', 24), ('11열왕기상', '1ki', 22), ('12열왕기하', '2ki', 25), ('13역대상', '1ch', 29), ('14역대하', '2ch', 36), ('15에스라', 'ezr', 10), ('16느헤미야', 'neh', 13), ('17에스더', 'est', 10), ('18욥기', 'job', 42), ('19시편', 'psa', 150), ('20잠언', 'pro', 31), ('21전도서', 'ecc', 12), ('22아가', 'sng', 8), ('23이사야', 'isa', 66), ('24예레미야', 'jer', 52), ('25예레미야애가', 'lam', 5), ('26에스겔', 'ezk', 48), ('27다니엘', 'dan', 12), ('28호세아', 'hos', 14), ('29요엘', 'jol', 3), ('30아모스', 'amo', 9), ('31오바댜', 'oba', 1), ('32요나', 'jnh', 4), ('33미가', 'mic', 7), ('34나훔', 'nam', 3), ('35하박국', 'hab', 3), ('36스바냐', 'zep', 3), ('37학개', 'hag', 2), ('38스가랴', 'zec', 14), ('39말라기', 'mal', 4), ('40마태복음', 'mat', 28), ('41마가복음', 'mrk', 16), ('42누가복음', 'luk', 24), ('43요한복음', 'jhn', 21), ('44사도행전', 'act', 28), ('45로마서', 'rom', 16), ('46고린도전서', '1co', 16), ('47고린도후서', '2co', 13), ('48갈라디아서', 'gal', 6), ('49에베소서', 'eph', 6), ('50빌립보서', 'php', 4), ('51골로새서', 'col', 4), ('52데살로니가전서', '1th', 5), ('53데살로니가후서', '2th', 3), ('54디모데전서', '1ti', 6), ('55디모데후서', '2ti', 4), ('56디도서', 'tit', 3), ('57빌레몬서', 'phm', 1), ('58히브리서', 'heb', 13), ('59야고보서', 'jas', 5), ('60베드로전서', '1pe', 5), ('61베드로후서', '2pe', 3), ('62요한1서', '1jn', 5), ('63요한2서', '2jn', 1), ('64요한3서', '3jn', 1), ('65유다서', 'jud', 1), ('66요한계시록', 'rev', 22)]

# %% [markdown]
# ### 성경약어표
#
# https://www.bskorea.or.kr/bible/korbib_shortword02.php

# %% [markdown]
# ᛜtes·ta·ment [téstǝmǝnt] n.
#
# ① 유언(장), 유서
# ┈┈• a person’s last will and ~ (죽은 후 재산처분에 관한) 유언(장)
# ┈┈• a military ~ (구두의) 군인유언.
# ② (신과 사람과의) 계약, 성약.
# ③ (the T-) 성서; 《구어》 신약성서
# ┈┈• ⇨OLD TESTAMENT, ⇨NEW TESTAMENT.
# ④ (사실·정당성 등의) 입증, 증거.
# ⑤ 신앙〔신조〕의 표명; 고백.

# %%
import requests
from bs4 import BeautifulSoup

def get_soup(url):
    print(url)
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    return soup


def get_new_book_abbr(table):
    book_names = []
    for item in table:
        tds = item.find_all('td')
        if len(tds) >= 3:
            book = tds[1].text
            abbr = tds[2].text
            book_name = (book, abbr)
            book_names.append(book_name)
    return book_names

def get_old_book_abbr(table):
    book_names = []
    for item in table:
        tds = item.find_all('td')
        if len(tds) >= 3:
            book = tds[1].text
            abbr = tds[2].text
            book_name = (book, abbr)
            book_names.append(book_name)
    return book_names



print(f'\n1. English Bible\n')

url = 'https://www.bskorea.or.kr/bible/korbib_shortword02.php'
soup = get_soup(url)
tables = soup.find('body').find('div').find_all('table')
print(len(tables))

old_books = get_old_book_abbr(table = tables[2].find_all('tr'))
print(len(old_books))
print(old_books)
new_books = get_old_book_abbr(table = tables[4].find_all('tr'))
print(len(new_books))
print(new_books)

print(f'\n2. Korean Bible\n')

url = 'https://www.bskorea.or.kr/bible/korbib_shortword01.php'
soup = get_soup(url)
tables = soup.find('body').find('div').find_all('table')
print(len(tables))

old_books_ko = get_old_book_abbr(table = tables[2].find_all('tr'))
print(len(old_books_ko))
print(old_books_ko)
books = get_old_book_abbr(table = tables[4].find_all('tr'))
new_books_ko = books#[:30]
print(len(new_books_ko))
print(new_books_ko)
# url = 'https://www.bskorea.or.kr/bible/korbib_shortword02.php'
# soup = get_soup(url)
# Out:
# 1. English Bible
#
# https://www.bskorea.or.kr/bible/korbib_shortword02.php
# 5
# 39
# [('Genesis', 'gen'), ('Exodus', 'exo'), ('Leviticus', 'lev'), ('Numbers', 'num'), ('Deuteronomy', 'deu'), ('Joshua', 'jos'), ('Judges', 'jdg'), ('Ruth', 'rut'), ('1 Samuel', '1sa'), ('2 Samuel', '2sa'), ('1 Kings', '1ki'), ('2 Kings', '2ki'), ('1 Chronicles', '1ch'), ('2 Chronicles', '2ch'), ('Ezra', 'ezr'), ('Nehemiah', 'neh'), ('Esther', 'est'), ('Job', 'job'), ('Psalms', 'psa'), ('Proverbs', 'pro'), ('Ecclesiastes', 'ecc'), ('Song of Songs', 'sng'), ('Isaiah', 'isa'), ('Jeremiah', 'jer'), ('Lamentations', 'lam'), ('Ezekiel\t', 'ezk'), ('Daniel', 'dan'), ('Hosea', 'hos'), ('Joel', 'jol'), ('Amos', 'amo'), ('Obadiah', 'oba'), ('Jonah', 'jnh'), ('Micah', 'mic'), ('Nahum', 'nam'), ('Habakkuk', 'hab'), ('Zephaniah', 'zep'), ('Haggai', 'hag'), ('Zechariah', 'zec'), ('Malachi', 'mal')]
# 27
# [('Matthew', 'mat'), ('Mark', 'mrk'), ('Luke', 'luk'), ('John', 'jhn'), ('Acts', 'act'), ('Romans', 'rom'), ('1 Corinthians', '1co'), ('2 Corinthians', '2co'), ('Galatians', 'gal'), ('Ephesians', 'eph'), ('Philippians', 'php'), ('Colossians', 'col'), ('1 Thessalonians', '1th'), ('2 Thessalonians', '2th'), ('1 Timothy', '1ti'), ('2 Timothy', '2ti'), ('Titus', 'tit'), ('Philemon', 'phm'), ('Hebrews', 'heb'), ('James', 'jas'), ('1 Peter', '1pe'), ('2 Peter', '2pe'), ('1 John', '1jn'), ('2 John', '2jn'), ('3 John', '3jn'), ('Jude', 'jud'), ('Revelation', 'rev')]
#
# 2. Korean Bible
#
# https://www.bskorea.or.kr/bible/korbib_shortword01.php
# 5
# 39
# [('창세기', '창'), ('출애굽기', '출'), ('레위기', '레'), ('민수기', '민'), ('신명기', '신'), ('여호수아', '수'), ('사사기', '삿'), ('룻기', '룻'), ('사무엘상', '삼상'), ('사무엘하', '삼하'), ('열왕기상', '왕상'), ('열왕기하', '왕하'), ('역대상', '대상'), ('역대하', '대하'), ('에스라', '스'), ('느헤미야', '느'), ('에스더', '에'), ('욥기', '욥'), ('시편', '시'), ('잠언', '잠'), ('전도서', '전'), ('아가', '아'), ('이사야', '사'), ('예레미야', '렘'), ('예레미야애가', '애'), ('에스겔', '겔'), ('다니엘', '단'), ('호세아', '호'), ('요엘', '욜'), ('아모스', '암'), ('오바댜', '옵'), ('요나', '욘'), ('미가', '미'), ('나훔', '나'), ('하박국', '합'), ('스바냐', '습'), ('학개', '학'), ('스가랴', '슥'), ('말라기', '말')]
# 39
# [('마태복음', '마'), ('마가복음', '막'), ('누가복음', '눅'), ('요한복음', '요'), ('사도행전', '행'), ('로마서', '롬'), ('고린도전서', '고전'), ('고린도후서', '고후'), ('갈라디아서', '갈'), ('에베소서', '엡'), ('빌립보서', '빌'), ('골로새서', '골'), ('데살로니가전서', '살전'), ('데살로니가후서', '살후'), ('디모데전서', '딤전'), ('디모데후서', '딤후'), ('디도서', '딛'), ('빌레몬서', '몬'), ('히브리서', '히'), ('야고보서', '약'), ('베드로전서', '벧전'), ('베드로후서', '벧후'), ('요한1서', '요일'), ('요한1서', '요1'), ('요한2서', '요이'), ('요한2서', '요2'), ('요한3서', '요삼'), ('요한3서', '요3'), ('유다서', '유'), ('요한계시록', '계'), ('토비트', '토비'), ('유딧', '유딧'), ('에스델 (제2경전/외경)', '에스(외)'), ('지혜서', '지혜'), ('집회서', '집회'), ('바룩', '바룩'), ('다니엘 (제2경전/외경)', '다니(외)'), ('마카베오상', '1마카'), ('마카베오하', '2마카')]

# %%
import pickle

# # print(len(old_books_ko))
# # print(old_books_ko)
# old_books_ko = dict(old_books_ko)
# with open('../bibles/old_bible_abbr_ko.pkl', 'wb') as f:
#     pickle.dump(old_books_ko, f)
    
with open('../bibles/old_bible_abbr_ko.pkl', 'rb') as f:
    old_bible_abbr_ko = pickle.load(f)
    
print(len(old_bible_abbr_ko))
print(old_bible_abbr_ko)

# 한글_신약성경_이름요약 = [('마태복음', '마'), ('마가복음', '막'), ('누가복음', '눅'), ('요한복음', '요'), 
#           ('사도행전', '행'), ('로마서', '롬'), ('고린도전서', '고전'), ('고린도후서', '고후'), 
#           ('갈라디아서', '갈'), ('에베소서', '엡'), ('빌립보서', '빌'), ('골로새서', '골'), 
#           ('데살로니가전서', '살전'), ('데살로니가후서', '살후'), ('디모데전서', '딤전'), 
#           ('디모데후서', '딤후'), ('디도서', '딛'), ('빌레몬서', '몬'), ('히브리서', '히'), 
#           ('야고보서', '약'), ('베드로전서', '벧전'), ('베드로후서', '벧후'), 
#           ('요한1서', '요1'), ('요한2서', '요2'), ('요한3서', '요3'), 
#           ('유다서', '유'), ('요한계시록', '계')]

# # print(len(한글_신약성경_이름요약))
# # # print(한글_신약성경_이름요약)
# # new_bible_abbr_ko = dict(한글_신약성경_이름요약)

# with open('../bibles/new_bible_abbr_ko.pkl', 'wb') as f:
#     pickle.dump(new_bible_abbr_ko, f)
    
with open('../bibles/new_bible_abbr_ko.pkl', 'rb') as f:
    new_bible_abbr_ko = pickle.load(f)
    
print(len(new_bible_abbr_ko))
print(new_bible_abbr_ko)
# Out:
# 39
# {'창세기': '창', '출애굽기': '출', '레위기': '레', '민수기': '민', '신명기': '신', '여호수아': '수', '사사기': '삿', '룻기': '룻', '사무엘상': '삼상', '사무엘하': '삼하', '열왕기상': '왕상', '열왕기하': '왕하', '역대상': '대상', '역대하': '대하', '에스라': '스', '느헤미야': '느', '에스더': '에', '욥기': '욥', '시편': '시', '잠언': '잠', '전도서': '전', '아가': '아', '이사야': '사', '예레미야': '렘', '예레미야애가': '애', '에스겔': '겔', '다니엘': '단', '호세아': '호', '요엘': '욜', '아모스': '암', '오바댜': '옵', '요나': '욘', '미가': '미', '나훔': '나', '하박국': '합', '스바냐': '습', '학개': '학', '스가랴': '슥', '말라기': '말'}
# 27
# {'마태복음': '마', '마가복음': '막', '누가복음': '눅', '요한복음': '요', '사도행전': '행', '로마서': '롬', '고린도전서': '고전', '고린도후서': '고후', '갈라디아서': '갈', '에베소서': '엡', '빌립보서': '빌', '골로새서': '골', '데살로니가전서': '살전', '데살로니가후서': '살후', '디모데전서': '딤전', '디모데후서': '딤후', '디도서': '딛', '빌레몬서': '몬', '히브리서': '히', '야고보서': '약', '베드로전서': '벧전', '베드로후서': '벧후', '요한1서': '요1', '요한2서': '요2', '요한3서': '요3', '유다서': '유', '요한계시록': '계'}

# %%
# 외경_이름요약 = [('토비트', '토비'), ('유딧', '유딧'), ('에스델 (제2경전/외경)', '에스(외)'),
#            ('지혜서', '지혜'), ('집회서', '집회'), ('바룩', '바룩'), 
#            ('다니엘 (제2경전/외경)', '다니(외)'), ('마카베오상', '1마카'), ('마카베오하', '2마카')]
# print(len(외경_이름요약))
# print(외경_이름요약)
# extra_new_bible_abbr_ko = 외경_이름요약
# extra_new_bible_abbr_ko = dict(extra_new_bible_abbr_ko)
# print(extra_new_bible_abbr_ko)


# with open('../bibles/extra_new_bible_abbr_ko.pkl', 'wb') as f:
#     pickle.dump(extra_new_bible_abbr_ko, f)
    
with open('../bibles/extra_new_bible_abbr_ko.pkl', 'rb') as f:
    extra_new_bible_abbr_ko = pickle.load(f)
    
print(len(extra_new_bible_abbr_ko))
print(extra_new_bible_abbr_ko)
# Out:
# 9
# {'토비트': '토비', '유딧': '유딧', '에스델 (제2경전/외경)': '에스(외)', '지혜서': '지혜', '집회서': '집회', '바룩': '바룩', '다니엘 (제2경전/외경)': '다니(외)', '마카베오상': '1마카', '마카베오하': '2마카'}

# %%
print(f'\n1. English Bible\n')

# url = 'https://www.bskorea.or.kr/bible/korbib_shortword02.php'
# soup = get_soup(url)
# tables = soup.find('body').find('div').find_all('table')
# print(len(tables))

# old_books = get_old_book_abbr(table = tables[2].find_all('tr'))
# print(len(old_books))
# print(old_books)
# new_books = get_old_book_abbr(table = tables[4].find_all('tr'))
# print(len(new_books))
# print(new_books)


# old_books = dict(old_books)
# new_books = dict(new_books)

# with open('../bibles/new_bible_abbr_en.pkl', 'wb') as f:
#     pickle.dump(new_books, f)
    
with open('../bibles/new_bible_abbr_en.pkl', 'rb') as f:
    new_bible_abbr_en = pickle.load(f)
    
print(len(new_bible_abbr_en))
print(new_bible_abbr_en)


# with open('../bibles/old_bible_abbr_en.pkl', 'wb') as f:
#     pickle.dump(old_books, f)
    
with open('../bibles/old_bible_abbr_en.pkl', 'rb') as f:
    old_bible_abbr_en = pickle.load(f)
    
print(len(old_bible_abbr_en))
print(old_bible_abbr_en)
# Out:
# 1. English Bible
#
# 27
# {'Matthew': 'mat', 'Mark': 'mrk', 'Luke': 'luk', 'John': 'jhn', 'Acts': 'act', 'Romans': 'rom', '1 Corinthians': '1co', '2 Corinthians': '2co', 'Galatians': 'gal', 'Ephesians': 'eph', 'Philippians': 'php', 'Colossians': 'col', '1 Thessalonians': '1th', '2 Thessalonians': '2th', '1 Timothy': '1ti', '2 Timothy': '2ti', 'Titus': 'tit', 'Philemon': 'phm', 'Hebrews': 'heb', 'James': 'jas', '1 Peter': '1pe', '2 Peter': '2pe', '1 John': '1jn', '2 John': '2jn', '3 John': '3jn', 'Jude': 'jud', 'Revelation': 'rev'}
# 39
# {'Genesis': 'gen', 'Exodus': 'exo', 'Leviticus': 'lev', 'Numbers': 'num', 'Deuteronomy': 'deu', 'Joshua': 'jos', 'Judges': 'jdg', 'Ruth': 'rut', '1 Samuel': '1sa', '2 Samuel': '2sa', '1 Kings': '1ki', '2 Kings': '2ki', '1 Chronicles': '1ch', '2 Chronicles': '2ch', 'Ezra': 'ezr', 'Nehemiah': 'neh', 'Esther': 'est', 'Job': 'job', 'Psalms': 'psa', 'Proverbs': 'pro', 'Ecclesiastes': 'ecc', 'Song of Songs': 'sng', 'Isaiah': 'isa', 'Jeremiah': 'jer', 'Lamentations': 'lam', 'Ezekiel\t': 'ezk', 'Daniel': 'dan', 'Hosea': 'hos', 'Joel': 'jol', 'Amos': 'amo', 'Obadiah': 'oba', 'Jonah': 'jnh', 'Micah': 'mic', 'Nahum': 'nam', 'Habakkuk': 'hab', 'Zephaniah': 'zep', 'Haggai': 'hag', 'Zechariah': 'zec', 'Malachi': 'mal'}

# %% [markdown]
# ### examples of bible books

# %%
import pandas as pd

df = pd.read_csv('../bibles/개역한글/06여호수아.csv')
print(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 657 entries, 0 to 656
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   book         657 non-null    object
#  1   book_en      657 non-null    object
#  2   chapter      657 non-null    int64
#  3   verse_no     657 non-null    object
#  4   verse        657 non-null    object
#  5   small_title  657 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 30.9+ KB
# None
#      book book_en  chapter verse_no  \
# 0    여호수아     jos        1     1
# 1    여호수아     jos        1     2
# 2    여호수아     jos        1     3
# 3    여호수아     jos        1     4
# 4    여호수아     jos        1     5
# ..    ...     ...      ...      ...
# 652  여호수아     jos       24    29
# 653  여호수아     jos       24    30
# 654  여호수아     jos       24    31
# 655  여호수아     jos       24    32
# 656  여호수아     jos       24    33
#
#                                                  verse            small_title
# 0    여호와의 종 모세가 죽은 후에 여호와께서 모세의 시종 눈의 아들 여호수아에게 일러 ...      여호와께서 여호수아에게 이르시다
# 1    내 종 모세가 죽었으니 이제 너는 이 모든 백성으로 더불어 일어나 이 요단을 건너 ...      여호와께서 여호수아에게 이르시다
# 2    내가 모세에게 말한 바와 같이 무릇 너희 발바닥으로 밟는 곳을 내가 다 너희에게 주었노니      여호와께서 여호수아에게 이르시다
# 3    곧 광야와 이 레바논에서부터 큰 하수 유브라데에 이르는 헷 족속의 온 땅과 또 해 ...      여호와께서 여호수아에게 이르시다
# 4    너의 평생에 너를 능히 당할 자 없으리니 내가 모세와 함께 있던것 같이 너와 함께 ...      여호와께서 여호수아에게 이르시다
# ..                                                 ...                    ...
# 652               이 일 후에 여호와의 종 눈의 아들 여호수아가 일백 십세에 죽으매  여호수아가 세겜에 모인 백성에게 이르다
# 653  무리가 그를 그의 기업의 경내 딤낫 세라에 장사하였으니 딤낫 세라는 에브라임 산지 ...  여호수아가 세겜에 모인 백성에게 이르다
# 654  이스라엘이 여호수아의 사는 날 동안과 여호수아 뒤에 생존한 장로들 곧 여호와께서 이...  여호수아가 세겜에 모인 백성에게 이르다
# 655  이스라엘 자손이 애굽에서 이끌어 낸 요셉의 뼈를 세겜에 장사하였으니 이곳은 야곱이 ...  여호수아가 세겜에 모인 백성에게 이르다
# 656  아론의 아들 엘르아살도 죽으매 무리가 그를 그 아들 비느하스가 에브라임 산지에서 받...  여호수아가 세겜에 모인 백성에게 이르다
#
# [657 rows x 6 columns]

# %%
df = pd.read_csv('../bibles/개역한글/02출애굽기.csv')
print(df.info())
display(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   book         1213 non-null   object
#  1   book_en      1213 non-null   object
#  2   chapter      1213 non-null   int64
#  3   verse_no     1213 non-null   object
#  4   verse        1213 non-null   object
#  5   small_title  1213 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 57.0+ KB
# None
#       book book_en  chapter verse_no  \
# 0     출애굽기     exo        1     1
# 1     출애굽기     exo        1     2
# 2     출애굽기     exo        1     3
# 3     출애굽기     exo        1     4
# 4     출애굽기     exo        1     5
# ...    ...     ...      ...      ...
# 1208  출애굽기     exo       40    34
# 1209  출애굽기     exo       40    35
# 1210  출애굽기     exo       40    36
# 1211  출애굽기     exo       40    37
# 1212  출애굽기     exo       40    38
#
#                                                   verse      small_title
# 0           야곱과 함께 각기 권속을 데리고 애굽에 이른 이스라엘 아들들의 이름은 이러하니  이스라엘 자손이 학대를 받다
# 1                                     르우벤과 시므온과 레위와 유다와  이스라엘 자손이 학대를 받다
# 2                                        잇사갈과 스불론과 베냐민과  이스라엘 자손이 학대를 받다
# 3                                       단과 납달리와 갓과 아셀이요  이스라엘 자손이 학대를 받다
# 4                     이미 애굽에 있는 요셉까지 야곱의 혈속이 모두 칠십인이었더라  이스라엘 자손이 학대를 받다
# ...                                                 ...              ...
# 1208                 그 후에 구름이 회막에 덮이고 여호와의 영광이 성막에 충만하매            성막 봉헌
# 1209  모세가 회막에 들어갈 수 없었으니 이는 구름이 회막 위에 덮이고 여호와의 영광이 성...            성막 봉헌
# 1210  구름이 성막 위에서 떠오를 때에는 이스라엘 자손이 그 모든 행하는 길에 앞으로 발행하였고            성막 봉헌
# 1211               구름이 떠오르지 않을 때에는 떠오르는 날까지 발행하지 아니하였으며            성막 봉헌
# 1212  낮에는 여호와의 구름이 성막 위에 있고 밤에는 불이 그 구름 가운데 있음을 이스라엘...            성막 봉헌
#
# [1213 rows x 6 columns]

# %% [markdown]
# ### All Bible Dataset

# %%
# %%time
path = r'D:\Korean_bible_project\bibles\개역한글'

bible_files = []
# all_bible_df = pd.DataFrame()
for entry in os.scandir(path):
    filename = entry.name
    filepath = os.path.join(path, filename)
    print(filename)
    bible_files.append(filepath)
#     bible_df = pd.read_csv(filepath)
#     all_bible_df = pd.concat([all_bible_df, bible_df], ignore_index=True)
# Out:
# 01창세기.csv
# 02출애굽기.csv
# 03레위기.csv
# 04민수기.csv
# 05신명기.csv
# 06여호수아.csv
# 07사사기.csv
# 08룻기.csv
# 09사무엘상.csv
# 10사무엘하.csv
# 11열왕기상.csv
# 12열왕기하.csv
# 13역대상.csv
# 14역대하.csv
# 15에스라.csv
# 16느헤미야.csv
# 17에스더.csv
# 18욥기.csv
# 19시편.csv
# 20잠언.csv
# 21전도서.csv
# 22아가.csv
# 23이사야.csv
# 24예레미야.csv
# 25예레미야애가.csv
# 26에스겔.csv
# 27다니엘.csv
# 28호세아.csv
# 29요엘.csv
# 30아모스.csv
# 31오바댜.csv
# 32요나.csv
# 33미가.csv
# 34나훔.csv
# 35하박국.csv
# 36스바냐.csv
# 37학개.csv
# 38스가랴.csv
# 39말라기.csv
# 40마태복음.csv
# 41마가복음.csv
# 42누가복음.csv
# 43요한복음.csv
# 44사도행전.csv
# 45로마서.csv
# 46고린도전서.csv
# 47고린도후서.csv
# 48갈라디아서.csv
# 49에베소서.csv
# 50빌립보서.csv
# 51골로새서.csv
# 52데살로니가전서.csv
# 53데살로니가후서.csv
# 54디모데전서.csv
# 55디모데후서.csv
# 56디도서.csv
# 57빌레몬서.csv
# 58히브리서.csv
# 59야고보서.csv
# 60베드로전서.csv
# 61베드로후서.csv
# 62요한1서.csv
# 63요한2서.csv
# 64요한3서.csv
# 65유다서.csv
# 66요한계시록.csv
# CPU times: total: 0 ns
# Wall time: 996 µs

# %%
print(len(bible_files))
print(bible_files[:5])
# Out:
# 66
# ['D:\\Korean_bible_project\\bibles\\개역한글\\01창세기.csv', 'D:\\Korean_bible_project\\bibles\\개역한글\\02출애굽기.csv', 'D:\\Korean_bible_project\\bibles\\개역한글\\03레위기.csv', 'D:\\Korean_bible_project\\bibles\\개역한글\\04민수기.csv', 'D:\\Korean_bible_project\\bibles\\개역한글\\05신명기.csv']

# %%
path = r'D:\Korean_bible_project\bibles'
filename = '성경_개역한글.csv'
filepath = os.path.join(path, filename)
# all_bible_df.to_csv(filepath, index=False)
all_bible_df = pd.read_csv(filepath)
print(all_bible_df.info())
display(all_bible_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31081 entries, 0 to 31080
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   book         31081 non-null  object
#  1   book_en      31081 non-null  object
#  2   chapter      31081 non-null  int64
#  3   verse_no     31081 non-null  object
#  4   verse        31081 non-null  object
#  5   small_title  28967 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.4+ MB
# None
#   book book_en  chapter verse_no  \
# 0  창세기     gen        1     1
# 1  창세기     gen        1     2
# 2  창세기     gen        1     3
# 3  창세기     gen        1     4
# 4  창세기     gen        1     5
#
#                                                verse small_title
# 0                                태초에 하나님이 천지를 창조하시니라       천지 창조
# 1       땅이 혼돈하고 공허하며 흑암이 깊음 위에 있고 하나님의 신은 수면에 운행하시니라       천지 창조
# 2                        하나님이 가라사대 빛이 있으라 하시매 빛이 있었고       천지 창조
# 3               그 빛이 하나님의 보시기에 좋았더라 하나님이 빛과 어두움을 나누사       천지 창조
# 4  빛을 낮이라 칭하시고 어두움을 밤이라 칭하시니라 저녁이 되며 아침이 되니 이는 첫째...       천지 창조

# %%
# duplication check
all_bible_df[all_bible_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [book, book_en, chapter, verse_no, verse, small_title]
# Index: []

# %% [markdown]
# ### Create a GitHub Repository:

# %%
print(datetime.now())
# Out:
# 2023-10-13 12:26:54.236662
